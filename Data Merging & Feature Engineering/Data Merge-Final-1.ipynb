# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import datetime
import time
import swifter

# %% [markdown]
# # Data Loading

# %%
AppLaunchedMod = pd.read_csv('./data_modded/AppLaunchedMod.csv',sep=',')
UTMVisitedMod = pd.read_csv('./data_modded/UTMVisitedMod.csv',sep=',')
RegistrationMod = pd.read_csv('./data_modded/RegistrationMod.csv',sep=',')
AppUninstalledMod = pd.read_csv('./data_modded/AppUninstalledMod.csv',sep=',')

# %% [markdown]
# # Check the shape of every dataset before combining them.

# %%
print("AppLaunchedMod:",AppLaunchedMod.shape)
print("UTMVisitedMod:",UTMVisitedMod.shape)
print("RegistrationMod:",RegistrationMod.shape)
print("AppUninstalledMod:",AppUninstalledMod.shape)
# Out:
# AppLaunchedMod: (2716093, 6)
# UTMVisitedMod: (495850, 6)
# RegistrationMod: (329579, 7)
# AppUninstalledMod: (326684, 6)

# %% [markdown]
# # Feature Engineering App Launch

# %%
AppLaunchedMod['Event'] = "App Launched"
user_frequency = AppLaunchedMod['UserId'].value_counts()
AppLaunchedMod = AppLaunchedMod.merge(user_frequency,how='inner',left_on='UserId',right_index=True)
AppLaunchedMod.head()
# Out:
#                               UserId                          UserId_x  State  \
# 0   a27134c322d4f56dabc106a6847cb96b  a27134c322d4f56dabc106a6847cb96b     50
# 13  a27134c322d4f56dabc106a6847cb96b  a27134c322d4f56dabc106a6847cb96b     50
# 25  a27134c322d4f56dabc106a6847cb96b  a27134c322d4f56dabc106a6847cb96b     50
# 41  a27134c322d4f56dabc106a6847cb96b  a27134c322d4f56dabc106a6847cb96b     50
# 52  a27134c322d4f56dabc106a6847cb96b  a27134c322d4f56dabc106a6847cb96b     50
#
#     Country  Device  OS             DateTime         Event  UserId_y
# 0         1       1   2  2017-01-06 00:00:04  App Launched       342
# 13        1       1   2  2017-01-06 00:01:04  App Launched       342
# 25        1       1   2  2017-01-06 00:02:08  App Launched       342
# 41        1       1   2  2017-01-06 00:03:12  App Launched       342
# 52        1       1   2  2017-01-06 00:04:12  App Launched       342

# %%
AppLaunchedMod.drop(['UserId_x'],axis=1,inplace=True)
AppLaunchedMod.rename({'UserId_y':'EventFrequency'},axis='columns',inplace=True)

# %%
AppLaunchedMod.head()
# Out:
#                               UserId  State  Country  Device  OS  \
# 0   a27134c322d4f56dabc106a6847cb96b     50        1       1   2
# 13  a27134c322d4f56dabc106a6847cb96b     50        1       1   2
# 25  a27134c322d4f56dabc106a6847cb96b     50        1       1   2
# 41  a27134c322d4f56dabc106a6847cb96b     50        1       1   2
# 52  a27134c322d4f56dabc106a6847cb96b     50        1       1   2
#
#                DateTime         Event  EventFrequency
# 0   2017-01-06 00:00:04  App Launched             342
# 13  2017-01-06 00:01:04  App Launched             342
# 25  2017-01-06 00:02:08  App Launched             342
# 41  2017-01-06 00:03:12  App Launched             342
# 52  2017-01-06 00:04:12  App Launched             342

# %%
AppLaunchedMod.isnull().sum()
# Out:
# UserId            0
# State             0
# Country           0
# Device            0
# OS                0
# DateTime          0
# Event             0
# EventFrequency    0
# dtype: int64

# %% [markdown]
# # Feature Engineering Registration

# %%
RegistrationMod['Event'] = "Registration"
user_frequency = RegistrationMod['UserId'].value_counts()
RegistrationMod = RegistrationMod.merge(user_frequency,how='inner',left_on='UserId',right_index=True)
RegistrationMod.head()
# Out:
#                              UserId                          UserId_x  State  \
# 0  d168e2b924124feaad13eae44a68fce9  d168e2b924124feaad13eae44a68fce9     35
# 1  deed7490952a6746610ee2ee9fd219b7  deed7490952a6746610ee2ee9fd219b7      7
# 2  13d9f55e297d7d9c219fbe9085e1006c  13d9f55e297d7d9c219fbe9085e1006c     35
# 3  fccc2c0abf5afabf242a70df7b4c9e69  fccc2c0abf5afabf242a70df7b4c9e69     39
# 4  9ff982b29d78cefc8eb5a3ffb7fd2a5d  9ff982b29d78cefc8eb5a3ffb7fd2a5d     38
#
#    Country  Device  OS         Status             DateTime         Event  \
# 0        1       1   2       Complete  2017-01-06 00:00:08  Registration
# 1       40       1   1      Completed  2017-01-06 00:00:08  Registration
# 2        1       1   2       Complete  2017-01-06 00:00:28  Registration
# 3        1       1   1      Completed  2017-01-06 00:00:52  Registration
# 4        1       1   1  Not Completed  2017-01-06 00:00:52  Registration
#
#    UserId_y
# 0         1
# 1         1
# 2         1
# 3         1
# 4         2

# %%
RegistrationMod.drop(['UserId_x'],axis=1,inplace=True)
RegistrationMod.rename({'UserId_y':'EventFrequency'},axis='columns',inplace=True)

# %%
RegistrationMod.head()
# Out:
#                              UserId  State  Country  Device  OS  \
# 0  d168e2b924124feaad13eae44a68fce9     35        1       1   2
# 1  deed7490952a6746610ee2ee9fd219b7      7       40       1   1
# 2  13d9f55e297d7d9c219fbe9085e1006c     35        1       1   2
# 3  fccc2c0abf5afabf242a70df7b4c9e69     39        1       1   1
# 4  9ff982b29d78cefc8eb5a3ffb7fd2a5d     38        1       1   1
#
#           Status             DateTime         Event  EventFrequency
# 0       Complete  2017-01-06 00:00:08  Registration               1
# 1      Completed  2017-01-06 00:00:08  Registration               1
# 2       Complete  2017-01-06 00:00:28  Registration               1
# 3      Completed  2017-01-06 00:00:52  Registration               1
# 4  Not Completed  2017-01-06 00:00:52  Registration               2

# %%
RegistrationMod.drop(['Status'],axis=1,inplace=True)
RegistrationMod.head()
# Out:
#                              UserId  State  Country  Device  OS  \
# 0  d168e2b924124feaad13eae44a68fce9     35        1       1   2
# 1  deed7490952a6746610ee2ee9fd219b7      7       40       1   1
# 2  13d9f55e297d7d9c219fbe9085e1006c     35        1       1   2
# 3  fccc2c0abf5afabf242a70df7b4c9e69     39        1       1   1
# 4  9ff982b29d78cefc8eb5a3ffb7fd2a5d     38        1       1   1
#
#               DateTime         Event  EventFrequency
# 0  2017-01-06 00:00:08  Registration               1
# 1  2017-01-06 00:00:08  Registration               1
# 2  2017-01-06 00:00:28  Registration               1
# 3  2017-01-06 00:00:52  Registration               1
# 4  2017-01-06 00:00:52  Registration               2

# %% [markdown]
# # Feature Engineering Utm visited

# %%
UTMVisitedMod['Event'] = "UTM Visited"
user_frequency = UTMVisitedMod['UserId'].value_counts()
UTMVisitedMod = UTMVisitedMod.merge(user_frequency,how='inner',left_on='UserId',right_index=True)
UTMVisitedMod.head()
# Out:
#                                  UserId                          UserId_x  \
# 0      66d4abf4f3b733c27591b3f47c85eff7  66d4abf4f3b733c27591b3f47c85eff7
# 25017  66d4abf4f3b733c27591b3f47c85eff7  66d4abf4f3b733c27591b3f47c85eff7
# 1      1a40d7e5b34131b097fac80cf982241b  1a40d7e5b34131b097fac80cf982241b
# 26766  1a40d7e5b34131b097fac80cf982241b  1a40d7e5b34131b097fac80cf982241b
# 27206  1a40d7e5b34131b097fac80cf982241b  1a40d7e5b34131b097fac80cf982241b
#
#        State  Country  Device  OS             DateTime        Event  UserId_y
# 0         37        1       1   1  2017-01-06 00:00:52  UTM Visited         2
# 25017     37        1       1   1  2017-01-15 17:06:16  UTM Visited         2
# 1         40        1       1   1  2017-01-06 00:00:56  UTM Visited        10
# 26766     40        1       1   1  2017-01-16 10:13:56  UTM Visited        10
# 27206     40        1       1   1  2017-01-16 12:33:28  UTM Visited        10

# %%
UTMVisitedMod.drop(['UserId_x'],axis=1,inplace=True)
UTMVisitedMod.rename({'UserId_y':'EventFrequency'},axis='columns',inplace=True)

# %%
UTMVisitedMod.head()
# Out:
#                                  UserId  State  Country  Device  OS  \
# 0      66d4abf4f3b733c27591b3f47c85eff7     37        1       1   1
# 25017  66d4abf4f3b733c27591b3f47c85eff7     37        1       1   1
# 1      1a40d7e5b34131b097fac80cf982241b     40        1       1   1
# 26766  1a40d7e5b34131b097fac80cf982241b     40        1       1   1
# 27206  1a40d7e5b34131b097fac80cf982241b     40        1       1   1
#
#                   DateTime        Event  EventFrequency
# 0      2017-01-06 00:00:52  UTM Visited               2
# 25017  2017-01-15 17:06:16  UTM Visited               2
# 1      2017-01-06 00:00:56  UTM Visited              10
# 26766  2017-01-16 10:13:56  UTM Visited              10
# 27206  2017-01-16 12:33:28  UTM Visited              10

# %%
UTMVisitedMod.isnull().sum()
# Out:
# UserId            0
# State             0
# Country           0
# Device            0
# OS                0
# DateTime          0
# Event             0
# EventFrequency    0
# dtype: int64

# %% [markdown]
# # Feature Engineering App Uninstall

# %%
AppUninstalledMod['Event'] = "App Uninstalled"
user_frequency = AppUninstalledMod['UserId'].value_counts()
AppUninstalledMod = AppUninstalledMod.merge(user_frequency,how='inner',left_on='UserId',right_index=True)
AppUninstalledMod.head()
# Out:
#                                   UserId                          UserId_x  \
# 0       0d5f4cc176a4e1c648a9b9b5dbe21d69  0d5f4cc176a4e1c648a9b9b5dbe21d69
# 549     0d5f4cc176a4e1c648a9b9b5dbe21d69  0d5f4cc176a4e1c648a9b9b5dbe21d69
# 199441  0d5f4cc176a4e1c648a9b9b5dbe21d69  0d5f4cc176a4e1c648a9b9b5dbe21d69
# 262026  0d5f4cc176a4e1c648a9b9b5dbe21d69  0d5f4cc176a4e1c648a9b9b5dbe21d69
# 291982  0d5f4cc176a4e1c648a9b9b5dbe21d69  0d5f4cc176a4e1c648a9b9b5dbe21d69
#
#         State  Country  Device  OS             DateTime            Event  \
# 0          47        1       1   1  2017-01-06 00:00:00  App Uninstalled
# 549        47        1       1   1  2017-01-06 02:58:00  App Uninstalled
# 199441     47        1       1   1  2017-04-22 02:04:00  App Uninstalled
# 262026     47        1       1   1  2017-05-17 02:34:00  App Uninstalled
# 291982     47        1       1   1  2017-05-30 02:28:00  App Uninstalled
#
#         UserId_y
# 0              5
# 549            5
# 199441         5
# 262026         5
# 291982         5

# %%
AppUninstalledMod.drop(['UserId_x'],axis=1,inplace=True)
AppUninstalledMod.rename({'UserId_y':'EventFrequency'},axis='columns',inplace=True)

# %%
AppUninstalledMod.head()
# Out:
#                                   UserId  State  Country  Device  OS  \
# 0       0d5f4cc176a4e1c648a9b9b5dbe21d69     47        1       1   1
# 549     0d5f4cc176a4e1c648a9b9b5dbe21d69     47        1       1   1
# 199441  0d5f4cc176a4e1c648a9b9b5dbe21d69     47        1       1   1
# 262026  0d5f4cc176a4e1c648a9b9b5dbe21d69     47        1       1   1
# 291982  0d5f4cc176a4e1c648a9b9b5dbe21d69     47        1       1   1
#
#                    DateTime            Event  EventFrequency
# 0       2017-01-06 00:00:00  App Uninstalled               5
# 549     2017-01-06 02:58:00  App Uninstalled               5
# 199441  2017-04-22 02:04:00  App Uninstalled               5
# 262026  2017-05-17 02:34:00  App Uninstalled               5
# 291982  2017-05-30 02:28:00  App Uninstalled               5

# %%
print("AppLaunchedMod:",AppLaunchedMod.shape)
print("UTMVisitedMod:",UTMVisitedMod.shape)
print("RegistrationMod:",RegistrationMod.shape)
print("AppUninstalledMod:",AppUninstalledMod.shape)
# Out:
# AppLaunchedMod: (2716093, 8)
# UTMVisitedMod: (495850, 8)
# RegistrationMod: (329579, 8)
# AppUninstalledMod: (326684, 8)

# %% [markdown]
# # Merging the above Events

# %%
final_data_1 = pd.DataFrame()

# %%
final_data_1 = final_data_1.append(RegistrationMod)
final_data_1.shape
# Out:
# (329579, 8)

# %%
final_data_1 = final_data_1.append(AppLaunchedMod)
final_data_1.shape
# Out:
# (3045672, 8)

# %%
final_data_1 = final_data_1.append(UTMVisitedMod)
final_data_1.shape
# Out:
# (3541522, 8)

# %%
final_data_1 = final_data_1.append(AppUninstalledMod)
final_data_1.shapeb
# Out:
# (3868206, 8)

# %%
final_data_1.head()
# Out:
#                              UserId  State  Country  Device  OS  \
# 0  d168e2b924124feaad13eae44a68fce9     35        1       1   2
# 1  deed7490952a6746610ee2ee9fd219b7      7       40       1   1
# 2  13d9f55e297d7d9c219fbe9085e1006c     35        1       1   2
# 3  fccc2c0abf5afabf242a70df7b4c9e69     39        1       1   1
# 4  9ff982b29d78cefc8eb5a3ffb7fd2a5d     38        1       1   1
#
#               DateTime         Event  EventFrequency
# 0  2017-01-06 00:00:08  Registration               1
# 1  2017-01-06 00:00:08  Registration               1
# 2  2017-01-06 00:00:28  Registration               1
# 3  2017-01-06 00:00:52  Registration               1
# 4  2017-01-06 00:00:52  Registration               2

# %%
final_data_1.sort_values(['UserId','DateTime'],axis=0,inplace=True)

# %%
final_data_1.head()
# Out:
#                                   UserId  State  Country  Device  OS  \
# 68491   0000146e97c32d369268e5ba5f4b907c     36        1       1   1
# 658199  0000146e97c32d369268e5ba5f4b907c     36        1       1   1
# 658809  0000146e97c32d369268e5ba5f4b907c     36        1       1   1
# 661623  0000146e97c32d369268e5ba5f4b907c     36        1       1   1
# 145813  0000146e97c32d369268e5ba5f4b907c     36        1       1   1
#
#                    DateTime         Event  EventFrequency
# 68491   2017-02-21 10:36:36  Registration               1
# 658199  2017-02-21 10:36:36  App Launched              14
# 658809  2017-02-21 12:16:20  App Launched              14
# 661623  2017-02-21 18:16:28  App Launched              14
# 145813  2017-02-21 18:16:28   UTM Visited               4

# %%
final_data_1.to_csv(path_or_buf='final_data_1.csv',sep=',',index=False)
