# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import datetime
import time
import swifter

# %%
data = pd.read_csv('./feature_engineered_data.csv')

# %%
data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  EventFrequency  \
# 0         NaN     36     NaN  App Launched              14
# 1         NaN     36     NaN  Registration               1
# 2         NaN     36     NaN  App Launched              14
# 3         NaN     36     NaN  App Launched              14
# 4         NaN     36     NaN   UTM Visited               4
#
#               DateTime     PreviousDateTime          LastSeenTimestamp  \
# 0  2017-02-21 10:36:36  2017-02-21 10:36:36  0 days 00:00:00.000000000
# ...

# %%
data.isnull().sum()
# Out:
# UserId                      0
# Category              3868206
# Country                     0
# Device                      0
# Genre                 3868206
# OS                          0
# ProgramType           3868206
# State                       0
# VideoId               3868206
# Event                       0
# EventFrequency              0
# DateTime                    0
# PreviousDateTime            0
# LastSeenTimestamp           0
# LastSeen(in Hours)          0
# LastEvent(in 48H)           0
# WatchedVideo                0
# dtype: int64

# %% [markdown]
# # Video Started in 48 Hours

# %%
data['WatchedVideo'].value_counts()
# Out:
# 1    7563657
# 0    1796525
# Name: WatchedVideo, dtype: int64

# %%
data['WatchedVideo(in 48H)'] = 1
data['WatchedVideo(in 48H)'] = data['WatchedVideo(in 48H)'].where(data['LastEvent(in 48H)']=='Yes',0)

# %%
data['WatchedVideo(in 48H)'].value_counts()
# Out:
# 1    8936368
# 0     423814
# Name: WatchedVideo(in 48H), dtype: int64

# %%
data['AppLaunchedFrequency'] = ''
data['AppLaunchedFrequency'] = data['AppLaunchedFrequency'].where((data['Event']!='App Launched'),data['EventFrequency'])
data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  EventFrequency  \
# 0         NaN     36     NaN  App Launched              14
# 1         NaN     36     NaN  Registration               1
# 2         NaN     36     NaN  App Launched              14
# 3         NaN     36     NaN  App Launched              14
# 4         NaN     36     NaN   UTM Visited               4
#
#               DateTime     PreviousDateTime          LastSeenTimestamp  \
# 0  2017-02-21 10:36:36  2017-02-21 10:36:36  0 days 00:00:00.000000000
# ...

# %%
data.AppLaunchedFrequency.value_counts()
# Out:
#        6644089
# 1       184637
# 2       164054
# 3       137820
# 4       113724
#         ...
# 215        215
# 203        203
# 194        194
# 180        180
# 179        179
# Name: AppLaunchedFrequency, Length: 523, dtype: int64

# %%
data['AppLaunchedFrequency'].replace('', np.nan,inplace=True)
data['AppLaunchedFrequency'] = data['AppLaunchedFrequency'].fillna(method='ffill')
print(data.isnull().sum())
data.head()
# Out:
# UserId                        0
# Category                3868206
# Country                       0
# Device                        0
# Genre                   3868206
# OS                            0
# ProgramType             3868206
# State                         0
# VideoId                 3868206
# Event                         0
# EventFrequency                0
# DateTime                      0
# PreviousDateTime              0
# LastSeenTimestamp             0
# LastSeen(in Hours)            0
# LastEvent(in 48H)             0
# WatchedVideo                  0
# WatchedVideo(in 48H)          0
# AppLaunchedFrequency          0
# dtype: int64
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# ...

# %%
data['RegistrationFrequency'] = ''
data['RegistrationFrequency'] = data['RegistrationFrequency'].where((data['Event']!='Registration'),data['EventFrequency'])

# %%
data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  EventFrequency  \
# 0         NaN     36     NaN  App Launched              14
# 1         NaN     36     NaN  Registration               1
# 2         NaN     36     NaN  App Launched              14
# 3         NaN     36     NaN  App Launched              14
# 4         NaN     36     NaN   UTM Visited               4
#
#               DateTime     PreviousDateTime          LastSeenTimestamp  \
# 0  2017-02-21 10:36:36  2017-02-21 10:36:36  0 days 00:00:00.000000000
# ...

# %%
data['RegistrationFrequency'].replace('', np.nan,inplace=True)
data['RegistrationFrequency'] = data['RegistrationFrequency'].fillna(method='ffill')
data.isnull().sum()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          1
# dtype: int64

# %%
data[data['RegistrationFrequency'].isnull()]
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  EventFrequency  \
# 0         NaN     36     NaN  App Launched              14
#
#               DateTime     PreviousDateTime          LastSeenTimestamp  \
# 0  2017-02-21 10:36:36  2017-02-21 10:36:36  0 days 00:00:00.000000000
#
#    LastSeen(in Hours) LastEvent(in 48H)  WatchedVideo  WatchedVideo(in 48H)  \
# 0                   0               Yes             1                     1
#
#    AppLaunchedFrequency  RegistrationFrequency
# 0                  14.0                    NaN

# %%
data['RegistrationFrequency'] = data['RegistrationFrequency'].fillna(method='bfill')
data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  EventFrequency  \
# 0         NaN     36     NaN  App Launched              14
# 1         NaN     36     NaN  Registration               1
# 2         NaN     36     NaN  App Launched              14
# 3         NaN     36     NaN  App Launched              14
# 4         NaN     36     NaN   UTM Visited               4
#
#               DateTime     PreviousDateTime          LastSeenTimestamp  \
# 0  2017-02-21 10:36:36  2017-02-21 10:36:36  0 days 00:00:00.000000000
# ...

# %%
data['UTMVisitedFrequency'] = ''
data['UTMVisitedFrequency'] = data['UTMVisitedFrequency'].where((data['Event']!='UTM Visited'),data['EventFrequency'])

# %%
data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  ...             DateTime  \
# 0         NaN     36     NaN  App Launched  ...  2017-02-21 10:36:36
# 1         NaN     36     NaN  Registration  ...  2017-02-21 10:36:36
# 2         NaN     36     NaN  App Launched  ...  2017-02-21 12:16:20
# 3         NaN     36     NaN  App Launched  ...  2017-02-21 18:16:28
# 4         NaN     36     NaN   UTM Visited  ...  2017-02-21 18:16:28
#
#       PreviousDateTime          LastSeenTimestamp LastSeen(in Hours)  \
# ...

# %%
data['UTMVisitedFrequency'].replace('', np.nan,inplace=True)
data.isnull().sum()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          0
# UTMVisitedFrequency      8864332
# dtype: int64

# %%
data['UTMVisitedFrequency'] = data['UTMVisitedFrequency'].fillna(method='ffill')
print(data.isnull().sum())
data.head()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          0
# UTMVisitedFrequency            4
# dtype: int64
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# ...

# %%
data[data['UTMVisitedFrequency'].isnull()]
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  ...             DateTime  \
# 0         NaN     36     NaN  App Launched  ...  2017-02-21 10:36:36
# 1         NaN     36     NaN  Registration  ...  2017-02-21 10:36:36
# 2         NaN     36     NaN  App Launched  ...  2017-02-21 12:16:20
# 3         NaN     36     NaN  App Launched  ...  2017-02-21 18:16:28
#
#       PreviousDateTime          LastSeenTimestamp LastSeen(in Hours)  \
# 0  2017-02-21 10:36:36  0 days 00:00:00.000000000                  0
# 1  2017-02-21 10:36:36  0 days 00:00:00.000000000                  0
# ...

# %%
data['UTMVisitedFrequency'] = data['UTMVisitedFrequency'].fillna(method='bfill')
print(data.isnull().sum())
data.head()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          0
# UTMVisitedFrequency            0
# dtype: int64
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# ...

# %%
data['VideoStartedFrequency'] = ''
data['VideoStartedFrequency'] = data['VideoStartedFrequency'].where((data['Event']!='Video Started'),data['EventFrequency'])
data.head(20)
# Out:
#                               UserId Category  Country  Device    Genre  OS  \
# 0   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 1   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 2   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 3   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 4   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 5   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 6   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 7   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 8   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 9   0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# 10  0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# ...

# %%
data['VideoStartedFrequency'].replace('', np.nan,inplace=True)
print(data.isnull().sum())
data['VideoStartedFrequency'] = data['VideoStartedFrequency'].fillna(method='ffill')
data.isnull().sum()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          0
# UTMVisitedFrequency            0
# VideoStartedFrequency    7563657
# dtype: int64
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ...

# %%
data[data['VideoStartedFrequency'].isnull()]
# Out:
#                              UserId Category  Country  Device    Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 5  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 6  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 7  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 8  0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 9  0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
#
#   ProgramType  State                           VideoId          Event  ...  \
# ...

# %%
data['VideoStartedFrequency'] = data['VideoStartedFrequency'].fillna(method='bfill')
data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  ...     PreviousDateTime  \
# 0         NaN     36     NaN  App Launched  ...  2017-02-21 10:36:36
# 1         NaN     36     NaN  Registration  ...  2017-02-21 10:36:36
# 2         NaN     36     NaN  App Launched  ...  2017-02-21 10:36:36
# 3         NaN     36     NaN  App Launched  ...  2017-02-21 12:16:20
# 4         NaN     36     NaN   UTM Visited  ...  2017-02-21 18:16:28
#
#            LastSeenTimestamp LastSeen(in Hours) LastEvent(in 48H)  \
# ...

# %%
data.isnull().sum()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          0
# UTMVisitedFrequency            0
# VideoStartedFrequency          0
# dtype: int64

# %%
data['VideoDetailsFrequency'] = ''
data['VideoDetailsFrequency'] = data['VideoDetailsFrequency'].where((data['Event']!='Video Details'),data['EventFrequency'])

# %%
data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId         Event  ...          LastSeenTimestamp  \
# 0         NaN     36     NaN  App Launched  ...  0 days 00:00:00.000000000
# 1         NaN     36     NaN  Registration  ...  0 days 00:00:00.000000000
# 2         NaN     36     NaN  App Launched  ...  0 days 01:39:44.000000000
# 3         NaN     36     NaN  App Launched  ...  0 days 06:00:08.000000000
# 4         NaN     36     NaN   UTM Visited  ...  0 days 00:00:00.000000000
#
#   LastSeen(in Hours) LastEvent(in 48H) WatchedVideo  WatchedVideo(in 48H)  \
# ...

# %%
data['VideoDetailsFrequency'].replace('', np.nan,inplace=True)
print(data.isnull().sum())
data['VideoDetailsFrequency'] = data['VideoDetailsFrequency'].fillna(method='ffill')
data.isnull().sum()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          0
# UTMVisitedFrequency            0
# VideoStartedFrequency          0
# VideoDetailsFrequency    5664731
# dtype: int64
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# ...

# %%
data['VideoDetailsFrequency'] = data['VideoDetailsFrequency'].fillna(method='bfill')
data.isnull().sum()
# Out:
# UserId                         0
# Category                 3868206
# Country                        0
# Device                         0
# Genre                    3868206
# OS                             0
# ProgramType              3868206
# State                          0
# VideoId                  3868206
# Event                          0
# EventFrequency                 0
# DateTime                       0
# PreviousDateTime               0
# LastSeenTimestamp              0
# LastSeen(in Hours)             0
# LastEvent(in 48H)              0
# WatchedVideo                   0
# WatchedVideo(in 48H)           0
# AppLaunchedFrequency           0
# RegistrationFrequency          0
# UTMVisitedFrequency            0
# VideoStartedFrequency          0
# VideoDetailsFrequency          0
# dtype: int64

# %%
data['AppUninstalledFrequency'] = ''
data['AppUninstalledFrequency'] = data['AppUninstalledFrequency'].where((data['Event']!='App Uninstalled'),data['EventFrequency'])

# %%
data['AppUninstalledFrequency'].replace('', np.nan,inplace=True)
print(data.isnull().sum())
data['AppUninstalledFrequency'] = data['AppUninstalledFrequency'].fillna(method='ffill')
data.isnull().sum()
# Out:
# UserId                           0
# Category                   3868206
# Country                          0
# Device                           0
# Genre                      3868206
# OS                               0
# ProgramType                3868206
# State                            0
# VideoId                    3868206
# Event                            0
# EventFrequency                   0
# DateTime                         0
# PreviousDateTime                 0
# LastSeenTimestamp                0
# LastSeen(in Hours)               0
# LastEvent(in 48H)                0
# WatchedVideo                     0
# WatchedVideo(in 48H)             0
# AppLaunchedFrequency             0
# RegistrationFrequency            0
# UTMVisitedFrequency              0
# VideoStartedFrequency            0
# VideoDetailsFrequency            0
# AppUninstalledFrequency    9033498
# dtype: int64
# UserId                           0
# Category                   3868206
# ...

# %%
data[data['AppUninstalledFrequency'].isnull()]
# Out:
#                               UserId Category  Country  Device    Genre  OS  \
# 0   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 1   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 2   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 3   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 4   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 5   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 6   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 7   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 8   0000146e97c32d369268e5ba5f4b907c      NaN        1       1      NaN   1
# 9   0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# 10  0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# ...

# %%
data['AppUninstalledFrequency'] = data['AppUninstalledFrequency'].fillna(method='bfill')
data.isnull().sum()
# Out:
# UserId                           0
# Category                   3868206
# Country                          0
# Device                           0
# Genre                      3868206
# OS                               0
# ProgramType                3868206
# State                            0
# VideoId                    3868206
# Event                            0
# EventFrequency                   0
# DateTime                         0
# PreviousDateTime                 0
# LastSeenTimestamp                0
# LastSeen(in Hours)               0
# LastEvent(in 48H)                0
# WatchedVideo                     0
# WatchedVideo(in 48H)             0
# AppLaunchedFrequency             0
# RegistrationFrequency            0
# UTMVisitedFrequency              0
# VideoStartedFrequency            0
# VideoDetailsFrequency            0
# AppUninstalledFrequency          0
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['UserId', 'Category', 'Country', 'Device', 'Genre', 'OS', 'ProgramType',
#        'State', 'VideoId', 'Event', 'EventFrequency', 'DateTime',
#        'PreviousDateTime', 'LastSeenTimestamp', 'LastSeen(in Hours)',
#        'LastEvent(in 48H)', 'WatchedVideo', 'WatchedVideo(in 48H)',
#        'AppLaunchedFrequency', 'RegistrationFrequency', 'UTMVisitedFrequency',
#        'VideoStartedFrequency', 'VideoDetailsFrequency',
#        'AppUninstalledFrequency'],
#       dtype='object')

# %%
data.nunique()
# Out:
# UserId                      466124
# Category                         2
# Country                         74
# Device                           4
# Genre                           54
# OS                               3
# ProgramType                      7
# State                          114
# VideoId                       7406
# Event                            6
# EventFrequency                 818
# DateTime                   2633881
# PreviousDateTime           2615470
# LastSeenTimestamp           291139
# LastSeen(in Hours)            3452
# LastEvent(in 48H)                2
# WatchedVideo                     2
# WatchedVideo(in 48H)             2
# AppLaunchedFrequency           522
# RegistrationFrequency           33
# UTMVisitedFrequency            145
# VideoStartedFrequency          413
# VideoDetailsFrequency          604
# AppUninstalledFrequency         20
# dtype: int64

# %% [markdown]
# # Subset Relevant Features

# %%
final_data = data[['UserId','Category','Country','Device','Genre','OS','ProgramType','State','VideoId',
                  'AppLaunchedFrequency','RegistrationFrequency','UTMVisitedFrequency',
                   'VideoStartedFrequency','VideoDetailsFrequency','AppUninstalledFrequency', 
                  'LastSeen(in Hours)','LastEvent(in 48H)','WatchedVideo','WatchedVideo(in 48H)']]

# %%
final_data.head()
# Out:
#                              UserId Category  Country  Device Genre  OS  \
# 0  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 1  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 2  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 3  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
# 4  0000146e97c32d369268e5ba5f4b907c      NaN        1       1   NaN   1
#
#   ProgramType  State VideoId  AppLaunchedFrequency  RegistrationFrequency  \
# 0         NaN     36     NaN                  14.0                    1.0
# 1         NaN     36     NaN                  14.0                    1.0
# 2         NaN     36     NaN                  14.0                    1.0
# 3         NaN     36     NaN                  14.0                    1.0
# 4         NaN     36     NaN                  14.0                    1.0
#
#    UTMVisitedFrequency  VideoStartedFrequency  VideoDetailsFrequency  \
# ...

# %%
final_data.shape
# Out:
# (9360182, 19)

# %% [markdown]
# # Get Data of Unique Users from relevant data

# %%
Data = final_data[final_data['VideoId'].notnull()]
print(Data.shape)
Data.head()
# Out:
# (5491976, 19)
#                               UserId Category  Country  Device    Genre  OS  \
# 9   0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# 10  0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# 11  0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# 13  0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
# 15  0000146e97c32d369268e5ba5f4b907c     vod         1       1   Drama    1
#
#    ProgramType  State                           VideoId  AppLaunchedFrequency  \
# 9    TV Shows      36  f053c42e98d50e06532ce8d65afb3ab3                  14.0
# 10    TV Shows     36  e0902e3677f8445c461a6e23882f6598                  14.0
# 11   TV Shows      36  291075c45a4b30a53a3123d3a57f8432                  14.0
# 13   TV Shows      36  d96be0b1386c42092c10ba1bd6a64167                  14.0
# 15   TV Shows      36  d96be0b1386c42092c10ba1bd6a64167                  14.0
#
# ...

# %%
Data.nunique()
# Out:
# UserId                     263783
# Category                        2
# Country                        31
# Device                          4
# Genre                          54
# OS                              3
# ProgramType                     7
# State                         104
# VideoId                      7406
# AppLaunchedFrequency          465
# RegistrationFrequency          32
# UTMVisitedFrequency           119
# VideoStartedFrequency         413
# VideoDetailsFrequency         604
# AppUninstalledFrequency        19
# LastSeen(in Hours)             83
# LastEvent(in 48H)               2
# WatchedVideo                    2
# WatchedVideo(in 48H)            2
# dtype: int64

# %%
Data_unique = Data.drop_duplicates(['UserId'])

# %%
Data_unique.shape
# Out:
# (263783, 19)

# %%
Data_unique.head()
# Out:
#                                UserId  Category  Country  Device     Genre  \
# 9    0000146e97c32d369268e5ba5f4b907c      vod         1       1    Drama
# 32   00001e3213a2159ed06f1db689c54fbb      vod        40       1   Comedy
# 42   00004010d92c2f13b824237bc323d58b      vod        40       2    Anime
# 57   000076c7bbdf7e4568777134cc4bec56      vod         1       1    Drama
# 103  0000e560394fce891dcf80218793d181   linear         1       1    Anime
#
#      OS ProgramType  State                           VideoId  \
# 9     1   TV Shows      36  f053c42e98d50e06532ce8d65afb3ab3
# 32    1     Movies      33  94e0e078a2107fd19e6b375e193c3a93
# 42    1   TV Shows      33  edfe3711d865215486344ee2a545c0c1
# 57    2    TV Shows     35  f0961889cad44180693b249ad0718b78
# 103   1   Channels      40  7215ee9c7d9dc229d2921a40e899ec5f
#
#      AppLaunchedFrequency  RegistrationFrequency  UTMVisitedFrequency  \
# 9                    14.0                    1.0                  4.0
# ...

# %%
Data_unique['WatchedVideo(in 48H)'].value_counts()
# Out:
# 1    263777
# 0         6
# Name: WatchedVideo(in 48H), dtype: int64

# %%
Data_unique['WatchedVideo(in 48H)'] = Data_unique['WatchedVideo(in 48H)'].where(Data_unique['WatchedVideo']==1,0)
Data_unique['WatchedVideo(in 48H)'].value_counts()
# Out:
# 1    223637
# 0     40146
# Name: WatchedVideo(in 48H), dtype: int64

# %%
Data_unique.head()
# Out:
#                                UserId  Category  Country  Device     Genre  \
# 9    0000146e97c32d369268e5ba5f4b907c      vod         1       1    Drama
# 32   00001e3213a2159ed06f1db689c54fbb      vod        40       1   Comedy
# 42   00004010d92c2f13b824237bc323d58b      vod        40       2    Anime
# 57   000076c7bbdf7e4568777134cc4bec56      vod         1       1    Drama
# 103  0000e560394fce891dcf80218793d181   linear         1       1    Anime
#
#      OS ProgramType  State                           VideoId  \
# 9     1   TV Shows      36  f053c42e98d50e06532ce8d65afb3ab3
# 32    1     Movies      33  94e0e078a2107fd19e6b375e193c3a93
# 42    1   TV Shows      33  edfe3711d865215486344ee2a545c0c1
# 57    2    TV Shows     35  f0961889cad44180693b249ad0718b78
# 103   1   Channels      40  7215ee9c7d9dc229d2921a40e899ec5f
#
#      AppLaunchedFrequency  RegistrationFrequency  UTMVisitedFrequency  \
# 9                    14.0                    1.0                  4.0
# ...

# %%
Data_unique.to_csv(path_or_buf='modelready_data.csv',sep=',',index=False)
